# %%
a=10
print(a)
# Out:
# 10

# %%
# convert integer to float
a=10
b=float(a)
print(b)
print(type(b))

# convert float to integer
c=9.25
d=int(c)
print(d)
print(type(d))

# convert integer to complex
e=95
f=complex(e)
print(f)
print(type(f))
# Out:
# 10.0
# <class 'float'>
# 9
# <class 'int'>
# (95+0j)
# <class 'complex'>

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      10
# b          float    10.0
