# %%
# 1 to 10 numbers printing program using loop


#for i in range(1,10):   
   #     print(i)


i=1
while i<=10:
   print(i)
   i+=1
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %% [markdown]
# 0 0
# 1 1
#
#
# (0 , 1)(2 , 3)
#
# 0 2
# 0 3
# 1 2
# 1 3
#
#
#
#
#
# 0 0
# 0 1
# 1  0
# 1 1
